# %%
# !python create_bel_file.py "../Preprocessing/neo4j_graph relations_15.01.26_updated_checked.xlsx" "bel-files/curated_bel_files.bel"
# Out:
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# obj is path(MESHD:"AIP")
# ...

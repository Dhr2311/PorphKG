# %%
import pandas as pd

# %%
kegg = pd.read_excel("Pathway_nodes.xlsx", 
                        sheet_name = "kegg", 
                        index_col = 0)

# %%
kegg
# Out:
#                                      Symbol  \
# Identifier
# 10720                               UGT2B11
# 10941                                UGT2A1
# 124454                                EARS2
# 1352                                  COX10
# 1355                                  COX15
# ...                                     ...
# C21835            12,18-Didecarboxysiroheme
# C22338                      Dihydro-heme d1
# C22339                              Heme d1
# C22450               5-Methoxybenzimidazole
# C22451      5-Methoxy-6-methylbenzimidazole
#
#                                                     full name          id1  \
# Identifier
# 10720        UDP glucuronosyltransferase family 2 member B11   KO:K00699]
# 10941        UDP glucuronosyltransferase family 2 member A...  KO:K00699]
# 124454             glutamyl-tRNA synthetase 2, mitochondrial   KO:K01885]
# 1352         cytochrome c oxidase assembly factor heme A:f...  KO:K02257]
# 1355              cytochrome c oxidase assembly factor COX15   KO:K02259]
# ...                                                       ...          ...
# C21835                                                    NaN          NaN
# C22338                                                    NaN          NaN
# C22339                                                    NaN          NaN
# C22450                                                    NaN          NaN
# C22451                                                    NaN          NaN
#
#                       id2
# Identifier
# 10720        EC:2.4.1.17]
# 10941        EC:2.4.1.17]
# 124454       EC:6.1.1.17]
# 1352        EC:2.5.1.141]
# 1355        EC:1.17.99.9]
# ...                   ...
# C21835                NaN
# C22338                NaN
# C22339                NaN
# C22450                NaN
# C22451                NaN
#
# [194 rows x 4 columns]

# %%
reactome = pd.read_excel("Pathway_nodes.xlsx", 
                        sheet_name = "reactome", 
                        index_col = 0)

# %%
reactome
# Out:
#                                 Symbol        MoleculeType     Unnamed: 3
# Identifier
# 29105                        zinc(2+)   Chemical Compounds   ChEBI:29105]
# 27889                         lead(0)   Chemical Compounds   ChEBI:27889]
# 356416            5-ammoniolevulinate   Chemical Compounds  ChEBI:356416]
# 58126             porphobilinogen(1-)   Chemical Compounds   ChEBI:58126]
# 15378                          hydron   Chemical Compounds   ChEBI:15378]
# ...                                ...                 ...            ...
# UniProt:P33527                   ABCC1            Proteins            NaN
# UniProt:P53004                   BLVRA            Proteins            NaN
# UniProt:P30043                   BLVRB            Proteins            NaN
# UniProt:O94956-3               SLCO2B1            Proteins            NaN
# UniProt:Q9Y6L6                 SLCO1B1            Proteins            NaN
#
# [79 rows x 3 columns]

# %%
reactome.columns
# Out:
# Index(['Symbol', 'MoleculeType', 'Unnamed: 3'], dtype='object')

# %%
wikipathways = pd.read_excel("Pathway_nodes.xlsx", 
                        sheet_name = "wiki", 
                        index_col = 0)

# %%
wikipathways
# Out:
#                                            Symbol         Type  \
# Identifier
# hmdb:HMDB0001957  Pentacarboxyl porphyrinogen III   Metabolite
# chebi:57306                     Protoporphyrin IX   Metabolite
# chebi:15437                  Uroporphyrinogen III   Metabolite
# chebi:28607                  Coproporphyrinogen I   Metabolite
# chebi:15435                 Protoporphyrinogen IX   Metabolite
# chebi:26355                             Protoheme   Metabolite
# chebi:17549             delta-aminolevulinic acid   Metabolite
# hmdb:HMDB0000123                          Glycine   Metabolite
# chebi:17381                       Porphobilinogen   Metabolite
# chebi:57845                   hydroxymethylbilane   Metabolite
# chebi:28766                    Uroporphyrinogen I   Metabolite
# chebi:15380                          succinyl-CoA   Metabolite
# hmdb:HMDB0001956       Heptacarboxylporphyrin III   Metabolite
# hmdb:HMDB0000789         Pentacarboxylporphyrin I   Metabolite
# hmdb:HMDB0001952        Hexacarboxylporphyrin III   Metabolite
# hmdb:HMDB0000743          Hexacarboxylporphyrin I   Metabolite
# chebi:89912                        Heptaporphyrin   Metabolite
# chebi:15439                Coproporphyrinogen III   Metabolite
# ncbigene:5498                                PPOX  GeneProduct
# ncbigene:3145                                HMBS  GeneProduct
# ncbigene:211                                ALAS1  GeneProduct
# ncbigene:210                                 ALAD  GeneProduct
# ncbigene:212                                ALAS2  GeneProduct
# ncbigene:7390                                UROS  GeneProduct
# ncbigene:7389                                UROD  GeneProduct
# ncbigene:1371                                CPOX  GeneProduct
# ncbigene:2235                                FECH  GeneProduct
#
#                                                           Comment
# Identifier
# hmdb:HMDB0001957  Alternative name: Pentacarboxyporphyrinogen III
# chebi:57306                                                   NaN
# chebi:15437                                                   NaN
# chebi:28607                                                   NaN
# chebi:15435                                                   NaN
# chebi:26355                                Alternative name: Heme
# chebi:17549                                                   NaN
# hmdb:HMDB0000123                        Alternative name: Glycine
# chebi:17381                                                   NaN
# chebi:57845                                                   NaN
# chebi:28766                                                   NaN
# chebi:15380                                                   NaN
# hmdb:HMDB0001956  Alternative name: Heptacarboxyporphyrinogen III
# hmdb:HMDB0000789    Alternative name: Pentacarboxyporphyrinogen I
# hmdb:HMDB0001952   Alternative name: Hexacarboxyporphyrinogen III
# hmdb:HMDB0000743     Alternative name: Hexacarboxyporphyrinogen I
# chebi:89912         Alternative name: Heptacarboxyporphyrinogen I
# chebi:15439                                                   NaN
# ncbigene:5498                      Alternative name:Proto-Oxidase
# ncbigene:3145                     Alternative name: PBG-Deaminase
# ncbigene:211                       Alternative name: ALA-Synthase
# ncbigene:210                    Alternative name: ALA-Dehydratase
# ncbigene:212                       Alternative name: ALA-Synthase
# ncbigene:7390                  Alternative name: UR0-111-synthase
# ncbigene:7389                 Alternative name: URO-Decarboxylase
# ncbigene:1371                    Alternative name: Copro-Oxidase
# ncbigene:2235                    Alternative name: Ferrocnelatase

# %%
import pandas as pd

def symbol_sets(df, col="Symbol"):
    # robust: handle missing col, whitespace, NaNs, duplicates
    if col not in df.columns:
        raise KeyError(f"Column '{col}' not found. Available: {list(df.columns)}")
    s = (
        df[col]
        .astype(str)                  # in case symbols are not strings
        .str.strip()                  # remove whitespace
        .replace({"nan": pd.NA})      # if NaN became "nan"
        .dropna()
    )
    return set(s)

def overlap_report(df1, df2, df3, col="Symbol"):
    s1 = symbol_sets(df1, col)
    s2 = symbol_sets(df2, col)
    s3 = symbol_sets(df3, col)

    # counts (unique symbols)
    counts_unique = {
        "df1_unique": len(s1),
        "df2_unique": len(s2),
        "df3_unique": len(s3),
    }

    # intersections (sets + counts)
    common_12 = s1 & s2
    common_13 = s1 & s3
    common_23 = s2 & s3
    common_123 = s1 & s2 & s3

    counts_overlap = {
        "common_df1_df2": len(common_12),
        "common_df1_df3": len(common_13),
        "common_df2_df3": len(common_23),
        "common_all_3": len(common_123),
    }

    # if you also want raw row counts (including duplicates / NaNs), use this:
    row_counts = {
        "df1_rows_nonnull": int(df1[col].notna().sum()),
        "df2_rows_nonnull": int(df2[col].notna().sum()),
        "df3_rows_nonnull": int(df3[col].notna().sum()),
    }

    results = {
        "row_counts": row_counts,
        "unique_counts": counts_unique,
        "overlap_counts": counts_overlap,
        "common_kegg_reactome": sorted(common_12),
        "common_kegg_wikipathways": sorted(common_13),
        "common_reactome_wikipathways": sorted(common_23),
        "common_all_3": sorted(common_123),
    }
    return results, (s1, s2, s3)

# --- usage ---
# assuming your dataframes are df1, df2, df3
results, (s1, s2, s3) = overlap_report(kegg, reactome, wikipathways, col="Symbol")

print("Row counts (non-null):", results["row_counts"])
print("Unique symbol counts:", results["unique_counts"])
print("Overlap counts:", results["overlap_counts"])

print("\nCommon to all 3 :", results["common_all_3"])
# Out:
# Row counts (non-null): {'df1_rows_nonnull': 194, 'df2_rows_nonnull': 79, 'df3_rows_nonnull': 27}
# Unique symbol counts: {'df1_unique': 194, 'df2_unique': 78, 'df3_unique': 27}
# Overlap counts: {'common_df1_df2': 18, 'common_df1_df3': 16, 'common_df2_df3': 8, 'common_all_3': 8}
#
# Common to all 3 : ['ALAD', 'ALAS1', 'ALAS2', 'CPOX', 'FECH', 'HMBS', 'PPOX', 'UROD']

# %%
import matplotlib.pyplot as plt

try:
    from matplotlib_venn import venn3
except ImportError as e:
    raise ImportError(
        "You need matplotlib-venn for the Venn diagram.\n"
        "Install with: pip install matplotlib-venn"
    ) from e

plt.figure()
venn3([s1, s2, s3], set_labels=("kegg", "reactome", "wikipathways"))
plt.title("Metabolism of porphyrins")
plt.savefig('MetabolismOfPorphyrins.png', format='png', dpi=600)
plt.show()

# %%
PKG = pd.read_excel("PKG_nodes_extracted.xlsx", 
                    sheet_name = "Sheet2",
                        index_col = 0)

# %%
import pandas as pd

def symbol_sets(df, col="Symbol"):
    if col not in df.columns:
        raise KeyError(f"Column '{col}' not found. Available: {list(df.columns)}")
    s = (
        df[col]
        .astype(str)
        .str.strip()
        .replace({"nan": pd.NA})
        .dropna()
    )
    return set(s)

def overlap_report_4(df1, df2, df3, df4, col="Symbol"):
    s1 = symbol_sets(df1, col)
    s2 = symbol_sets(df2, col)
    s3 = symbol_sets(df3, col)
    s4 = symbol_sets(df4, col)

    unique_counts = {
        "df1_unique": len(s1),
        "df2_unique": len(s2),
        "df3_unique": len(s3),
        "df4_unique": len(s4),
    }

    row_counts = {
        "df1_rows_nonnull": int(df1[col].notna().sum()),
        "df2_rows_nonnull": int(df2[col].notna().sum()),
        "df3_rows_nonnull": int(df3[col].notna().sum()),
        "df4_rows_nonnull": int(df4[col].notna().sum()),
    }

    # pairwise intersections
    pairs = {
        "common_df1_df2": s1 & s2,
        "common_df1_df3": s1 & s3,
        "common_df1_df4": s1 & s4,
        "common_df2_df3": s2 & s3,
        "common_df2_df4": s2 & s4,
        "common_df3_df4": s3 & s4,
    }

    # triple intersections
    triples = {
        "common_df1_df2_df3": s1 & s2 & s3,
        "common_df1_df2_df4": s1 & s2 & s4,
        "common_df1_df3_df4": s1 & s3 & s4,
        "common_df2_df3_df4": s2 & s3 & s4,
    }

    # all four
    common_all_4 = s1 & s2 & s3 & s4

    overlap_counts = {k: len(v) for k, v in pairs.items()}
    overlap_counts.update({k: len(v) for k, v in triples.items()})
    overlap_counts["common_all_4"] = len(common_all_4)

    results = {
        "row_counts": row_counts,
        "unique_counts": unique_counts,
        "overlap_counts": overlap_counts,
        **{k: sorted(v) for k, v in pairs.items()},
        **{k: sorted(v) for k, v in triples.items()},
        "common_all_4": sorted(common_all_4),
    }
    return results, (s1, s2, s3, s4)

# --- usage ---
# assuming your dataframes are df1, df2, df3, df4
results, (s1, s2, s3, s4) = overlap_report_4(kegg, reactome, wikipathways, PKG, col="Symbol")

print("Row counts (non-null):", results["row_counts"])
print("Unique symbol counts:", results["unique_counts"])
print("Overlap counts:", results["overlap_counts"])

print("\nCommon to all 4 :", results["common_all_4"])
# Out:
# Row counts (non-null): {'df1_rows_nonnull': 194, 'df2_rows_nonnull': 79, 'df3_rows_nonnull': 27, 'df4_rows_nonnull': 347}
# Unique symbol counts: {'df1_unique': 194, 'df2_unique': 78, 'df3_unique': 27, 'df4_unique': 347}
# Overlap counts: {'common_df1_df2': 18, 'common_df1_df3': 16, 'common_df1_df4': 14, 'common_df2_df3': 8, 'common_df2_df4': 13, 'common_df3_df4': 13, 'common_df1_df2_df3': 8, 'common_df1_df2_df4': 9, 'common_df1_df3_df4': 10, 'common_df2_df3_df4': 8, 'common_all_4': 8}
#
# Common to all 4 : ['ALAD', 'ALAS1', 'ALAS2', 'CPOX', 'FECH', 'HMBS', 'PPOX', 'UROD']

# %%
PKG
# Out:
#                                    Unnamed: 1  Unnamed: 2  Unnamed: 3 Symbol
# ALL
# p(HGNC:'ALAS1')                           NaN         NaN         NaN  ALAS1
# p(HGNC:'HMOX1')                           NaN         NaN         NaN  HMOX1
# p(HGNC:'PLCD1')                           NaN         NaN         NaN  PLCD1
# p(HGNC:'HAMP')                            NaN         NaN         NaN   HAMP
# p(HGNC:'ALAD')                            NaN         NaN         NaN   ALAD
# ...                                       ...         ...         ...    ...
# a(CHEMBL:'clodronate')                    NaN         NaN         NaN    NaN
# a(CHEMBL:'hydroxyproline')                NaN         NaN         NaN    NaN
# p(PFAM:'Ferritin')                        NaN         NaN         NaN    NaN
# a(GO:'IgG')                               NaN         NaN         NaN    NaN
# a(SNOMED:'Hexacarboxylporphyrin')         NaN         NaN         NaN    NaN
#
# [365 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

# pip install upsetplot
from upsetplot import UpSet, from_contents

contents = {
    "KEGG": s1,
    "Reactome": s2,
    "Wikipathways": s3,
    "PorphyriaKG": s4,
}

data = from_contents(contents)
plt.figure()
UpSet(data, show_counts=True).plot()
plt.suptitle("Metabolism of porphyrins (all 4)")
plt.savefig('MetabolismOfPorphyrins_all4.png', format='png', dpi=600)
plt.show()

# %%
len(s1)
# Out:
# 194

# %%
import pandas as pd

def symbol_sets(df, col="symbol"):
    if col not in df.columns:
        raise KeyError(f"Column '{col}' not found. Available: {list(df.columns)}")
    s = (
        df[col]
        .astype(str)
        .str.strip()
        .replace({"nan": pd.NA})
        .dropna()
    )
    return set(s)

def overlap_report_4(df1, df2, df3, df4, col="symbol"):
    s1 = symbol_sets(df1, col)
    s2 = symbol_sets(df2, col)
    s3 = symbol_sets(df3, col)
    s4 = symbol_sets(df4, col)

    unique_counts = {
        "df1_unique": len(s1),
        "df2_unique": len(s2),
        "df3_unique": len(s3),
        "df4_unique": len(s4),
    }

    row_counts = {
        "df1_rows_nonnull": int(df1[col].notna().sum()),
        "df2_rows_nonnull": int(df2[col].notna().sum()),
        "df3_rows_nonnull": int(df3[col].notna().sum()),
        "df4_rows_nonnull": int(df4[col].notna().sum()),
    }

    # pairwise intersections
    pairs = {
        "common_df1_df2": s1 & s2,
        "common_df1_df3": s1 & s3,
        "common_df1_df4": s1 & s4,
        "common_df2_df3": s2 & s3,
        "common_df2_df4": s2 & s4,
        "common_df3_df4": s3 & s4,
    }

    # triple intersections
    triples = {
        "common_df1_df2_df3": s1 & s2 & s3,
        "common_df1_df2_df4": s1 & s2 & s4,
        "common_df1_df3_df4": s1 & s3 & s4,
        "common_df2_df3_df4": s2 & s3 & s4,
    }

    # all four
    common_all_4 = s1 & s2 & s3 & s4

    overlap_counts = {k: len(v) for k, v in pairs.items()}
    overlap_counts.update({k: len(v) for k, v in triples.items()})
    overlap_counts["common_all_4"] = len(common_all_4)

    results = {
        "row_counts": row_counts,
        "unique_counts": unique_counts,
        "overlap_counts": overlap_counts,
        **{k: sorted(v) for k, v in pairs.items()},
        **{k: sorted(v) for k, v in triples.items()},
        "common_all_4": sorted(common_all_4),
    }
    return results, (s1, s2, s3, s4)

# --- usage ---
# assuming your dataframes are df1, df2, df3, df4
results, (s1, s2, s3, s4) = overlap_report_4(df1, df2, df3, df4, col="symbol")

print("Row counts (non-null):", results["row_counts"])
print("Unique symbol counts:", results["unique_counts"])
print("Overlap counts:", results["overlap_counts"])

print("\nCommon to all 4 (first 50):", results["common_all_4"][:50])

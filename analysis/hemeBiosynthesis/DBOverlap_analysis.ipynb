# %%
import pandas as pd

# %%
# kegg = pd.read_excel("All.xlsx", 
#                         sheet_name = "KEGG", 
#                         index_col = 0)

# %%
# kegg
# Out:
#                                      Symbol  \
# Identifier
# 10720                               UGT2B11
# 10941                                UGT2A1
# 124454                                EARS2
# 1352                                  COX10
# 1355                                  COX15
# ...                                     ...
# C21835            12,18-Didecarboxysiroheme
# C22338                      Dihydro-heme d1
# C22339                              Heme d1
# C22450               5-Methoxybenzimidazole
# C22451      5-Methoxy-6-methylbenzimidazole
#
#                                                     full name          id1  \
# Identifier
# 10720        UDP glucuronosyltransferase family 2 member B11   KO:K00699]
# 10941        UDP glucuronosyltransferase family 2 member A...  KO:K00699]
# 124454             glutamyl-tRNA synthetase 2, mitochondrial   KO:K01885]
# 1352         cytochrome c oxidase assembly factor heme A:f...  KO:K02257]
# 1355              cytochrome c oxidase assembly factor COX15   KO:K02259]
# ...                                                       ...          ...
# C21835                                                    NaN          NaN
# C22338                                                    NaN          NaN
# C22339                                                    NaN          NaN
# C22450                                                    NaN          NaN
# C22451                                                    NaN          NaN
#
#                       id2
# Identifier
# 10720        EC:2.4.1.17]
# 10941        EC:2.4.1.17]
# 124454       EC:6.1.1.17]
# 1352        EC:2.5.1.141]
# 1355        EC:1.17.99.9]
# ...                   ...
# C21835                NaN
# C22338                NaN
# C22339                NaN
# C22450                NaN
# C22451                NaN
#
# [194 rows x 4 columns]

# %%
reactome = pd.read_excel("Pathway_nodes.xlsx", 
                        sheet_name = "reactome", 
                        index_col = 0)

# %%
reactome
# Out:
#                                         Symbol
# NaN                                       ALAD
# NaN                                       HMBS
# NaN                                       FECH
# NaN                                        ALB
# NaN                                      ABCG2
# NaN                                     FLVCR1
# NaN                                       UROD
# NaN                                        Mgu
# NaN                                      COX10
# NaN                                       CPOX
# NaN                                       PPOX
# NaN                                      COX15
# NaN                                     FLVCR1
# NaN                                      ALAS2
# NaN                                      ALAS1
# NaN                                  zinc(2+)
# NaN                                   lead(0)
# NaN                       5-ammoniolevulinate
# NaN                       porphobilinogen(1-)
# NaN                                    hydron
# NaN                                     water
# NaN                            dipyrromethane
# NaN                                  ammonium
# NaN                   preuroporphyrinogen(8-)
# NaN                                  iron(2+)
# NaN                        protoporphyrin(2-)
# NaN                                    heme b
# NaN                    uroporphyrinogen I(8-)
# NaN                coproporphyrinogen III(4-)
# NaN                           ferroheme b(2-)
# NaN                                   ATP(4-)
# NaN                                   ADP(3-)
# NaN                         hydrogenphosphate
# NaN                  uroporphyrinogen III(8-)
# NaN                            carbon dioxide
# NaN  2-trans,6-trans-farnesyl diphosphate(3-)
# NaN                           ferroheme o(2-)
# NaN                           diphosphate(3-)
# NaN                                  dioxygen
# NaN                    protoporphyrinogen(2-)
# NaN                                   FAD(3-)
# NaN                         hydrogen peroxide
# NaN                         hydrogen acceptor
# NaN                           ferroheme a(2-)
# NaN                            hydrogen donor
# NaN                  coproporphyrinogen I(4-)
# NaN                          succinyl-CoA(5-)
# NaN                        glycine zwitterion
# NaN                            coenzyme A(4-)

# %%
reactome.columns
# Out:
# Index(['Symbol', 'MoleculeType', 'Unnamed: 3'], dtype='object')

# %%
wikipathways = pd.read_excel("Pathway_nodes.xlsx", 
                        sheet_name = "wiki", 
                        index_col = 0)

# %%
wikipathways
# Out:
#                      Symbol
# NaN   delta-aminolevulinate
# NaN                      O₂
# NaN         porphobilinogen
# NaN                     NH₃
# NaN                      H⁺
# NaN                    H₂O₂
# NaN                     CoA
# NaN    uroporphyrinogen III
# NaN                     CO₂
# NaN            succinyl-CoA
# NaN                 Glycine
# NaN                     H₂O
# NaN  coproporphyrinogen III
# NaN         Porphobilinogen
# NaN     hydroxymethylbilane
# NaN                     H₂O
# NaN                    Fe²⁺
# NaN               protoheme
# NaN       protoporphyrin IX
# NaN                   ALAS2
# NaN                    FECH
# NaN                    PPOX
# NaN                    CPOX
# NaN                    HMBS
# NaN                   ALAS1
# NaN                    ALAD
# NaN                    UROS

# %%
PKG = pd.read_excel("../PKG_nodes_extracted.xlsx", 
                    sheet_name = "Sheet2",
                        index_col = 0)

# %%
PKG
# Out:
#                                    Unnamed: 1  Unnamed: 2  Unnamed: 3 Symbol
# ALL
# p(HGNC:'ALAS1')                           NaN         NaN         NaN  ALAS1
# p(HGNC:'HMOX1')                           NaN         NaN         NaN  HMOX1
# p(HGNC:'PLCD1')                           NaN         NaN         NaN  PLCD1
# p(HGNC:'HAMP')                            NaN         NaN         NaN   HAMP
# p(HGNC:'ALAD')                            NaN         NaN         NaN   ALAD
# ...                                       ...         ...         ...    ...
# a(CHEMBL:'clodronate')                    NaN         NaN         NaN    NaN
# a(CHEMBL:'hydroxyproline')                NaN         NaN         NaN    NaN
# p(PFAM:'Ferritin')                        NaN         NaN         NaN    NaN
# a(GO:'IgG')                               NaN         NaN         NaN    NaN
# a(SNOMED:'Hexacarboxylporphyrin')         NaN         NaN         NaN    NaN
#
# [365 rows x 4 columns]

# %%
import pandas as pd

def symbol_sets(df, col="Symbol"):
    # robust: handle missing col, whitespace, NaNs, duplicates
    if col not in df.columns:
        raise KeyError(f"Column '{col}' not found. Available: {list(df.columns)}")
    s = (
        df[col]
        .astype(str)                  # in case symbols are not strings
        .str.strip()                  # remove whitespace
        .replace({"nan": pd.NA})      # if NaN became "nan"
        .dropna()
    )
    return set(s)

def overlap_report(df1, df2, col="Symbol"):
    s1 = symbol_sets(df1, col)
    s2 = symbol_sets(df2, col)

    # counts (unique symbols)
    counts_unique = {
        "df1_unique": len(s1),
        "df2_unique": len(s2),
    }

    # intersections (sets + counts)
    common_12 = s1 & s2

    counts_overlap = {
        "common_df1_df2": len(common_12),
        
    }

    # if you also want raw row counts (including duplicates / NaNs), use this:
    row_counts = {
        "df1_rows_nonnull": int(df1[col].notna().sum()),
        "df2_rows_nonnull": int(df2[col].notna().sum()),
        
    }

    results = {
        "row_counts": row_counts,
        "unique_counts": counts_unique,
        "overlap_counts": counts_overlap,
        "common_wiki_reactome": sorted(common_12),
        
    }
    return results, (s1, s2)

# --- usage ---
# assuming your dataframes are df1, df2, df3
results, (s1, s2,) = overlap_report(reactome, wikipathways, col="Symbol")

print("Row counts (non-null):", results["row_counts"])
print("Unique symbol counts:", results["unique_counts"])
print("Overlap counts:", results["overlap_counts"])

print("\nCommon to all 2 :", results["common_df1_df2"])
# Out:
# Row counts (non-null): {'df1_rows_nonnull': 49, 'df2_rows_nonnull': 27}
# Unique symbol counts: {'df1_unique': 48, 'df2_unique': 26}
# Overlap counts: {'common_df1_df2': 7}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 58
#      55 print("Unique symbol counts:", results["unique_counts"])
#      56 print("Overlap counts:", results["overlap_counts"])
# ---> 58 print("\nCommon to all 2 :", results["common_df1_df2"])
#
# KeyError: 'common_df1_df2'

# %%
import matplotlib.pyplot as plt

try:
    from matplotlib_venn import venn2
except ImportError as e:
    raise ImportError(
        "You need matplotlib-venn for the Venn diagram.\n"
        "Install with: pip install matplotlib-venn"
    ) from e

plt.figure()
venn2([s1, s2], set_labels=("reactome", "wikipathways"))
plt.title("Heme biosynthesis")
plt.savefig('Heme biosynthesis.png', format='png', dpi=600)
plt.show()

# %%
import pandas as pd

def symbol_sets(df, col="Symbol"):
    # robust: handle missing col, whitespace, NaNs, duplicates
    if col not in df.columns:
        raise KeyError(f"Column '{col}' not found. Available: {list(df.columns)}")
    s = (
        df[col]
        .astype(str)                  # in case symbols are not strings
        .str.strip()                  # remove whitespace
        .replace({"nan": pd.NA})      # if NaN became "nan"
        .dropna()
    )
    return set(s)

def overlap_report(df1, df2, df3, col="Symbol"):
    s1 = symbol_sets(df1, col)
    s2 = symbol_sets(df2, col)
    s3 = symbol_sets(df3, col)

    # counts (unique symbols)
    counts_unique = {
        "df1_unique": len(s1),
        "df2_unique": len(s2),
        "df3_unique": len(s3),
    }

    # intersections (sets + counts)
    common_12 = s1 & s2
    common_13 = s1 & s3
    common_23 = s2 & s3
    common_123 = s1 & s2 & s3

    counts_overlap = {
        "common_df1_df2": len(common_12),
        "common_df1_df3": len(common_13),
        "common_df2_df3": len(common_23),
        "common_all_3": len(common_123),
    }

    # if you also want raw row counts (including duplicates / NaNs), use this:
    row_counts = {
        "df1_rows_nonnull": int(df1[col].notna().sum()),
        "df2_rows_nonnull": int(df2[col].notna().sum()),
        "df3_rows_nonnull": int(df3[col].notna().sum()),
    }

    results = {
        "row_counts": row_counts,
        "unique_counts": counts_unique,
        "overlap_counts": counts_overlap,
        "common_kegg_reactome": sorted(common_12),
        "common_kegg_wikipathways": sorted(common_13),
        "common_reactome_wikipathways": sorted(common_23),
        "common_all_3": sorted(common_123),
    }
    return results, (s1, s2, s3)

# --- usage ---
# assuming your dataframes are df1, df2, df3
results, (s1, s2, s3) = overlap_report(PKG, reactome, wikipathways, col="Symbol")

print("Row counts (non-null):", results["row_counts"])
print("Unique symbol counts:", results["unique_counts"])
print("Overlap counts:", results["overlap_counts"])

print("\nCommon to all 3 :", results["common_all_3"])
# Out:
# Row counts (non-null): {'df1_rows_nonnull': 347, 'df2_rows_nonnull': 49, 'df3_rows_nonnull': 27}
# Unique symbol counts: {'df1_unique': 347, 'df2_unique': 48, 'df3_unique': 26}
# Overlap counts: {'common_df1_df2': 10, 'common_df1_df3': 13, 'common_df2_df3': 7, 'common_all_3': 7}
#
# Common to all 3 : ['ALAD', 'ALAS1', 'ALAS2', 'CPOX', 'FECH', 'HMBS', 'PPOX']

# %%
import matplotlib.pyplot as plt

# pip install upsetplot
from upsetplot import UpSet, from_contents

contents = {
    "PorphyriaKG": s1,
    "Reactome": s2,
    "Wikipathways": s3,
}

data = from_contents(contents)
plt.figure()
UpSet(data, show_counts=True).plot()
plt.suptitle("Heme biosynthesis (all 3)")
plt.savefig('HemeBiosynthesis_all4.png', format='png', dpi=600)
plt.show()

# %%
len(s1)
# Out:
# 194

# %%
import pandas as pd

def symbol_sets(df, col="symbol"):
    if col not in df.columns:
        raise KeyError(f"Column '{col}' not found. Available: {list(df.columns)}")
    s = (
        df[col]
        .astype(str)
        .str.strip()
        .replace({"nan": pd.NA})
        .dropna()
    )
    return set(s)

def overlap_report_4(df1, df2, df3, df4, col="symbol"):
    s1 = symbol_sets(df1, col)
    s2 = symbol_sets(df2, col)
    s3 = symbol_sets(df3, col)
    s4 = symbol_sets(df4, col)

    unique_counts = {
        "df1_unique": len(s1),
        "df2_unique": len(s2),
        "df3_unique": len(s3),
        "df4_unique": len(s4),
    }

    row_counts = {
        "df1_rows_nonnull": int(df1[col].notna().sum()),
        "df2_rows_nonnull": int(df2[col].notna().sum()),
        "df3_rows_nonnull": int(df3[col].notna().sum()),
        "df4_rows_nonnull": int(df4[col].notna().sum()),
    }

    # pairwise intersections
    pairs = {
        "common_df1_df2": s1 & s2,
        "common_df1_df3": s1 & s3,
        "common_df1_df4": s1 & s4,
        "common_df2_df3": s2 & s3,
        "common_df2_df4": s2 & s4,
        "common_df3_df4": s3 & s4,
    }

    # triple intersections
    triples = {
        "common_df1_df2_df3": s1 & s2 & s3,
        "common_df1_df2_df4": s1 & s2 & s4,
        "common_df1_df3_df4": s1 & s3 & s4,
        "common_df2_df3_df4": s2 & s3 & s4,
    }

    # all four
    common_all_4 = s1 & s2 & s3 & s4

    overlap_counts = {k: len(v) for k, v in pairs.items()}
    overlap_counts.update({k: len(v) for k, v in triples.items()})
    overlap_counts["common_all_4"] = len(common_all_4)

    results = {
        "row_counts": row_counts,
        "unique_counts": unique_counts,
        "overlap_counts": overlap_counts,
        **{k: sorted(v) for k, v in pairs.items()},
        **{k: sorted(v) for k, v in triples.items()},
        "common_all_4": sorted(common_all_4),
    }
    return results, (s1, s2, s3, s4)

# --- usage ---
# assuming your dataframes are df1, df2, df3, df4
results, (s1, s2, s3, s4) = overlap_report_4(df1, df2, df3, df4, col="symbol")

print("Row counts (non-null):", results["row_counts"])
print("Unique symbol counts:", results["unique_counts"])
print("Overlap counts:", results["overlap_counts"])

print("\nCommon to all 4 (first 50):", results["common_all_4"][:50])
